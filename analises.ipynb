# %%
# Importando o módulo de análise de qualidade de dados
from dataquality_module import DataQuality

# %%
# Ccaminho para o dataset
dataset_path = 'dataset/campeonato-brasileiro-full.csv'

# %%
# Nome da coluna de data (considerando o formato dd/mm/yyyy)
date_column_name = 'data'

# %%
# Criando a instância da classe DataQuality com o caminho do dataset e a coluna de data
dq = DataQuality(filepath=dataset_path, date_column=date_column_name)
# Out:
# Arquivo carregado com sucesso: dataset/campeonato-brasileiro-full.csv

# %%
# Executando a análise de qualidade de dados para os últimos 10 anos
dq.run_analysis(max_categories=30)
# Out:
# Iniciando análise de qualidade de dados...
#
# Filtrando dados para os últimos 10 anos...
# Dados filtrados para os últimos 10 anos a partir de 2013-12-06
#
# Contagem de valores nulos:
# ID                      0
# rodata                  0
# data                    0
# hora                    0
# mandante                0
# visitante               0
# formacao_mandante     378
# formacao_visitante    378
# tecnico_mandante       14
# tecnico_visitante      14
# vencedor                0
# arena                   0
# mandante_Placar         0
# visitante_Placar        0
# mandante_Estado         0
# visitante_Estado        0
# dtype: int64
#
# Contagem de valores únicos:
# ID                    3809
# rodata                  38
# data                  1014
# hora                   177
# mandante                36
# visitante               34
# formacao_mandante       21
# formacao_visitante      21
# tecnico_mandante       214
# tecnico_visitante      215
# ...
